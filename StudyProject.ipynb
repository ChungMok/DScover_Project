# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# 데이터 불러오기
df = pd.read_csv("C:/Users/Admin/OneDrive/바탕 화면/전국주차장정보표준데이터.csv", encoding = 'cp949')

# %%
# 데이터 확인
df.head()
# Out:
#         주차장관리번호     주차장명 주차장구분 주차장유형                    소재지도로명주소  \
# 0  184-1-000038  산성동제2노상    공영    노상       대전광역시 중구 대둔산로466번길 17
# 1  184-1-000039  산성동제3노상    공영    노상            대전광역시 중구 보문산로 31
# 2  184-1-000040  산성동제4노상    공영    노상       대전광역시 중구 대둔산로480번길 41
# 3  184-1-000041  산성동제5노상    공영    노상  대전광역시 중구 유등천동로 292번길 89-14
# 4  184-1-000042  산성동제6노상    공영    노상             대전광역시 중구 산성로 32
#
#                소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법 특기사항  \
# 0  대전광역시 중구 산성동 145-40     14    4    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
# 1    대전광역시 중구 산성동 78-5     43    4    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
# 2  대전광역시 중구 산성동 136-95     19    4    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
# 3    대전광역시 중구 산성동 36-1     84    4    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
# 4     대전광역시 중구 산성동 321     30    4    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
#
#            관리기관명          전화번호         위도          경도     데이터기준일자   제공기관코드  \
# ...

# %%
df.columns
# Out:
# Index(['주차장관리번호', '주차장명', '주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수',
#        '급지구분', '부제시행구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
#        '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
#        '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '결제방법', '특기사항',
#        '관리기관명', '전화번호', '위도', '경도', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# 주차장관리번호            0
# 주차장명               0
# 주차장구분              0
# 주차장유형              0
# 소재지도로명주소        7048
# 소재지지번주소          958
# 주차구획수              0
# 급지구분               0
# 부제시행구분             0
# 운영요일               0
# 평일운영시작시각           0
# 평일운영종료시각           0
# 토요일운영시작시각          0
# 토요일운영종료시각          0
# 공휴일운영시작시각          0
# 공휴일운영종료시각          0
# 요금정보               0
# 주차기본시간             0
# 주차기본요금          2658
# 추가단위시간          8774
# 추가단위요금          8789
# 1일주차권요금적용시간    10515
# 1일주차권요금         9957
# 월정기권요금         10025
# 결제방법            9915
# 특기사항           11910
# 관리기관명              0
# 전화번호            2424
# 위도              2289
# 경도              2301
# 데이터기준일자            0
# 제공기관코드             0
# 제공기관명              0
# dtype: int64

# %%
# 주소 정리
df[(df['소재지도로명주소'].isnull())&(df['소재지지번주소'].isnull())]
# Out:
# Empty DataFrame
# Columns: [주차장관리번호, 주차장명, 주차장구분, 주차장유형, 소재지도로명주소, 소재지지번주소, 주차구획수, 급지구분, 부제시행구분, 운영요일, 평일운영시작시각, 평일운영종료시각, 토요일운영시작시각, 토요일운영종료시각, 공휴일운영시작시각, 공휴일운영종료시각, 요금정보, 주차기본시간, 주차기본요금, 추가단위시간, 추가단위요금, 1일주차권요금적용시간, 1일주차권요금, 월정기권요금, 결제방법, 특기사항, 관리기관명, 전화번호, 위도, 경도, 데이터기준일자, 제공기관코드, 제공기관명]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[df['소재지도로명주소'].isnull()]
# Out:
#             주차장관리번호           주차장명 주차장구분 주차장유형 소재지도로명주소  \
# 173    194-2-000046     일산동(961-1)    공영    노외      NaN
# 210    194-2-000054       슬도 공영주차장    공영    노외      NaN
# 211    194-2-000055  전하1동(544-133)    공영    노외      NaN
# 212    194-2-000057     방어동(355-7)    공영    노외      NaN
# 213    194-2-000058        전하공영주차장    공영    노외      NaN
# ...             ...            ...   ...   ...      ...
# 14754  222-2-000018        진접 제4공영    공영    노외      NaN
# 14757  222-2-000021        사능 제1공영    공영    노외      NaN
# 14758  222-2-000022        양정 제1공영    공영    노외      NaN
# 14759  222-2-000023        화도 제3공영    공영    노외      NaN
# 14760  222-2-000024        와부 제4공영    공영    노외      NaN
#
#                                    소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  \
# 173                     울산광역시 동구 일산동 961-1     30    1    미시행  평일+토요일+공휴일
# 210                       울산광역시 동구 방어동 2-3     37    1    미시행  평일+토요일+공휴일
# ...

# %%
df1 = df

# %%
df1.loc[df1['소재지도로명주소'].isnull(), "소재지도로명주소"] = df1['소재지지번주소']
df1
# Out:
#             주차장관리번호           주차장명 주차장구분 주차장유형                    소재지도로명주소  \
# 0      184-1-000038        산성동제2노상    공영    노상       대전광역시 중구 대둔산로466번길 17
# 1      184-1-000039        산성동제3노상    공영    노상            대전광역시 중구 보문산로 31
# 2      184-1-000040        산성동제4노상    공영    노상       대전광역시 중구 대둔산로480번길 41
# 3      184-1-000041        산성동제5노상    공영    노상  대전광역시 중구 유등천동로 292번길 89-14
# 4      184-1-000042        산성동제6노상    공영    노상             대전광역시 중구 산성로 32
# ...             ...            ...   ...   ...                         ...
# 14796  260-2-000032    대화체육관 옆 주차장    공영    노외       강원도 평창군 대화면 대화1길 28-5
# 14797  260-2-000033  대화중고등학교 앞 주차장    공영    노외      강원도 평창군 대화면 대화중앙로 32-8
# 14798  260-2-000034      법장사입구 주차장    공영    노외        강원도 평창군 대화면 고대동길 168
# 14799  260-2-000035  면사무소앞 주차장(신설)    공영    노외         강원도 평창군 대화면 남산2길 20
# 14800  260-2-000036           대화의원    공영    노외       강원도 평창군 대화면 대화1길 38-3
#
# ...

# %%
df1['소재지도로명주소'].isnull().sum()
# Out:
# 0

# %%
df1.iloc[173, :]
# Out:
# 주차장관리번호              194-2-000046
# 주차장명                   일산동(961-1)
# 주차장구분                          공영
# 주차장유형                          노외
# 소재지도로명주소       울산광역시 동구 일산동 961-1
# 소재지지번주소        울산광역시 동구 일산동 961-1
# 주차구획수                          30
# 급지구분                            1
# 부제시행구분                        미시행
# 운영요일                   평일+토요일+공휴일
# 평일운영시작시각                    00:00
# 평일운영종료시각                    23:59
# 토요일운영시작시각                   00:00
# 토요일운영종료시각                   23:59
# 공휴일운영시작시각                   00:00
# 공휴일운영종료시각                   23:59
# 요금정보                           무료
# 주차기본시간                        0.0
# 주차기본요금                        0.0
# 추가단위시간                        0.0
# 추가단위요금                          0
# 1일주차권요금적용시간                   0.0
# 1일주차권요금                       0.0
# 월정기권요금                        0.0
# 결제방법                          NaN
# 특기사항                          NaN
# 관리기관명                   울산광역시 동구청
# ...

# %%
# 서울만 추출
df2 = df1[(df1['소재지도로명주소'].str.contains('서울'))]
df2.shape
# Out:
# (953, 33)

# %%
df2.head()
# Out:
#            주차장관리번호  주차장명 주차장구분 주차장유형             소재지도로명주소  \
# 1387  108-1-000030  아카데미    공영    노상   서울특별시 강북구 4.19로25길
# 1388  108-2-000026  수유쌈지    공영    노외    서울특별시 강북구 도봉로 265
# 1389  108-1-000031  교육청길    공영    노상  서울특별시 강북구 도봉로20가길 3
# 1390  108-2-000016   오패산    공영    노외  서울특별시 강북구 도봉로34길 54
# 1391  108-2-000005   미아동    공영    노외  서울특별시 강북구 도봉로61길 46
#
#                     소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ...    월정기권요금  \
# 1387   서울특별시 강북구 인수동 543-76     37    3    미시행  평일+토요일+공휴일  ...  100000.0
# 1388    서울특별시 강북구 수유동 612-6     19    1    미시행  평일+토요일+공휴일  ...  150000.0
# 1389   서울특별시 강북구 송중동 137-19     80    3    미시행  평일+토요일+공휴일  ...  100000.0
# 1390  서울특별시 강북구 미아동 133-100     76    5    미시행      평일+토요일  ...   60000.0
# 1391  서울특별시 강북구 미아동 222-100    155    5    미시행  평일+토요일+공휴일  ...   80000.0
#
#          결제방법 특기사항      관리기관명         전화번호         위도          경도     데이터기준일자  \
# 1387  카드+계좌이체  NaN  강북구도시관리공단  02-944-3025  37.625824  127.015692  2022-10-04
# ...

# %%
df2['제공기관명'].unique()
# Out:
# array(['서울특별시 강북구', '서울특별시금천구시설관리공단', '서울특별시 영등포구', '서울특별시 양천구',
#        '서울특별시 도봉구', '강북구도시관리공단', '서울특별시 노원구', '서울특별시 중구', '서울특별시 종로구',
#        '경상북도 영주시', '서울특별시 강서구', '서울특별시 금천구', '서울특별시 광진구', '서울특별시 동작구',
#        '서울특별시 서대문구', '서울특별시 구로구', '서울특별시 성북구', '서울특별시 관악구', '서울특별시 중랑구',
#        '서울특별시 동대문구', '서울특별시 은평구', '서울특별시 서초구', '서울특별시 강남구', '서울특별시 용산구',
#        '서울특별시 강동구', '서울시설공단', '서울특별시 송파구', '서울특별시성동구도시관리공단'], dtype=object)

# %%
df2[(df2['제공기관명']=='경상북도 영주시')]
# Out:
#            주차장관리번호         주차장명 주차장구분 주차장유형                        소재지도로명주소  \
# 4490  356-2-000004  하망동 3공영 주차장    공영    노외  경상북도 영주시 하망동 326-10(서울산부인과 건너)
#
#                              소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ...  \
# 4490  경상북도 영주시 하망동 326-10(서울산부인과 건너)     37    1    미시행  평일+토요일+공휴일  ...
#
#        월정기권요금     결제방법                     특기사항      관리기관명          전화번호  위도  \
# 4490  70000.0  현금+신용카드  공휴일+야간무료동·하절기 이용가능시간상이함  경상북도 영주시청  054-639-6843 NaN
#
#       경도     데이터기준일자   제공기관코드     제공기관명
# 4490 NaN  2022-06-15  5090000  경상북도 영주시
#
# [1 rows x 33 columns]

# %%
df2 = df2.drop(index=4490, axis=0)
df2['제공기관명'].unique()
# Out:
# array(['서울특별시 강북구', '서울특별시금천구시설관리공단', '서울특별시 영등포구', '서울특별시 양천구',
#        '서울특별시 도봉구', '강북구도시관리공단', '서울특별시 노원구', '서울특별시 중구', '서울특별시 종로구',
#        '서울특별시 강서구', '서울특별시 금천구', '서울특별시 광진구', '서울특별시 동작구', '서울특별시 서대문구',
#        '서울특별시 구로구', '서울특별시 성북구', '서울특별시 관악구', '서울특별시 중랑구', '서울특별시 동대문구',
#        '서울특별시 은평구', '서울특별시 서초구', '서울특별시 강남구', '서울특별시 용산구', '서울특별시 강동구',
#        '서울시설공단', '서울특별시 송파구', '서울특별시성동구도시관리공단'], dtype=object)

# %%
df2.shape
# Out:
# (952, 33)

# %%
# 필요한 열 추출
df2.columns
# Out:
# Index(['주차장관리번호', '주차장명', '주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수',
#        '급지구분', '부제시행구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
#        '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
#        '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '결제방법', '특기사항',
#        '관리기관명', '전화번호', '위도', '경도', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
df3 = df2[['주차장구분','주차장유형','소재지도로명주소', '소재지지번주소', '주차구획수', '급지구분', '운영요일', '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각',
       '토요일운영종료시각', '공휴일운영시작시각', '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금',
       '추가단위시간', '추가단위요금', '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '위도', '경도', '제공기관명']]

# %%
df3.columns
# Out:
# Index(['주차장구분', '주차장유형', '소재지도로명주소', '소재지지번주소', '주차구획수', '급지구분', '운영요일',
#        '평일운영시작시각', '평일운영종료시각', '토요일운영시작시각', '토요일운영종료시각', '공휴일운영시작시각',
#        '공휴일운영종료시각', '요금정보', '주차기본시간', '주차기본요금', '추가단위시간', '추가단위요금',
#        '1일주차권요금적용시간', '1일주차권요금', '월정기권요금', '위도', '경도', '제공기관명'],
#       dtype='object')

# %%
df3.shape
# Out:
# (952, 24)

# %%
df3.to_csv('studyproject_data.csv')

# %%
t1 = df[(df['제공기관명']=='서울특별시 서초구')]
t1
# Out:
#             주차장관리번호         주차장명 주차장구분 주차장유형                 소재지도로명주소  \
# 11964  121-1-000001        반포복개천    공영    노상      서울특별시 서초구 서초중앙로 255
# 11965  121-1-000002  방배복개도로 제1지역    공영    노상        서울특별시 서초구 방배천로 16
# 11966  121-1-000003  방배복개도로 제2지역    공영    노상        서울특별시 서초구 동작대로 68
# 11967  121-1-000004          방배역    공영    노상      서울특별시 서초구 방배로 100-2
# 11968  121-1-000005        방배중앙로    공영    노상     서울특별시 서초구 방배중앙로27길 2
# 11969  121-1-000006        방배사이길    공영    노상        서울특별시 서초구 방배로 248
# 11970  121-2-000001        교대역동측    공영    노외       서울특별시 서초구 서초대로 314
# 11971  121-2-000002     양재시민의숲동측    공영    노외      서울특별시 서초구 강남대로 45-2
# 11972  121-2-000003      청계산근린광장    공영    노외       서울특별시 서초구 청계산로 218
# 11973  121-2-000004         반포서래    공영    노외      서울특별시 서초구 사평대로22길31
# 11977  121-2-000005        청계산청룡    공영    노외     서울특별시 서초구 청계산로15길 31
# 11978  121-2-000008           양재    공영    노외    서울특별시 서초구 양재천로 125-10
# ...

# %%
t = df[(df['소재지도로명주소'].str.contains('마포', na = False))]
t
# Out:
#             주차장관리번호       주차장명 주차장구분 주차장유형                소재지도로명주소  \
# 8056   319-3-000016  부안누에타운주차장    공영    부설  전라북도 부안군 변산면 마포리 87-26
# 12965  113-2-000001      마포유수지    공영    노외      서울특별시 마포구 마포대로1길 9
# 12966  113-2-000002        망원동    공영    노외      서울특별시 마포구 월드컵로 131
#
#                       소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법  \
# 8056   전라북도 부안군 변산면 마포리 87-26     93   기타    미시행  평일+토요일+공휴일  ...    NaN  NaN
# 12965      서울특별시 마포구 마포동 36-1    505    2    미시행  평일+토요일+공휴일  ...    NaN  NaN
# 12966    서울특별시 마포구 망원동 478-10     20    4    미시행  평일+토요일+공휴일  ...    NaN  NaN
#
#       특기사항      관리기관명          전화번호         위도          경도     데이터기준일자  \
# 8056   NaN  전라북도 부안군청  063-580-4616  35.632291  126.514237  2022-11-14
# 12965  NaN     서울시설공단  02-2290-6093  37.539109  126.940920  2021-07-30
# 12966  NaN     서울시설공단           NaN  37.559654  126.904276  2021-07-30
#
#         제공기관코드     제공기관명
# 8056   4790000  전라북도 부안군
# 12965  B553774    서울시설공단
# ...

# %%
t1 = df[(df['소재지지번주소'].str.contains('마포', na = False))]
t1
# Out:
#             주차장관리번호       주차장명 주차장구분 주차장유형                소재지도로명주소  \
# 8056   319-3-000016  부안누에타운주차장    공영    부설  전라북도 부안군 변산면 마포리 87-26
# 12965  113-2-000001      마포유수지    공영    노외      서울특별시 마포구 마포대로1길 9
# 12966  113-2-000002        망원동    공영    노외      서울특별시 마포구 월드컵로 131
#
#                       소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법  \
# 8056   전라북도 부안군 변산면 마포리 87-26     93   기타    미시행  평일+토요일+공휴일  ...    NaN  NaN
# 12965      서울특별시 마포구 마포동 36-1    505    2    미시행  평일+토요일+공휴일  ...    NaN  NaN
# 12966    서울특별시 마포구 망원동 478-10     20    4    미시행  평일+토요일+공휴일  ...    NaN  NaN
#
#       특기사항      관리기관명          전화번호         위도          경도     데이터기준일자  \
# 8056   NaN  전라북도 부안군청  063-580-4616  35.632291  126.514237  2022-11-14
# 12965  NaN     서울시설공단  02-2290-6093  37.539109  126.940920  2021-07-30
# 12966  NaN     서울시설공단           NaN  37.559654  126.904276  2021-07-30
#
#         제공기관코드     제공기관명
# 8056   4790000  전라북도 부안군
# 12965  B553774    서울시설공단
# ...
